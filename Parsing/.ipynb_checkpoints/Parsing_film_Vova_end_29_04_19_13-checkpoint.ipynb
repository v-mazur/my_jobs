# %%
import pandas as pd
import requests 
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
resultat = {'names_film': [], 'raiting': [], 'janre': [], 'director': []}

for i in range (1, 153, 50):
    urles = 'https://www.imdb.com/search/title/?release_date=2010-01-01,2022-12-31&start=' + str(i)
    request = requests.get(urles)
    soup = bs(request.text, "html.parser")
    
    name_film = soup.find_all('h3', class_='lister-item-header') 
    for name in name_film:
        resultat['names_film'].append(name.text.strip())


    reiting_info = soup.find_all('span', class_='value')
    for reiting in reiting_info:
        resultat['raiting'].append(reiting.text.strip())
        
        
    janre_info = soup.find_all('span', class_='genre')
    for info_jan in janre_info:
        resultat['janre'].append(info_jan.text.strip())
        
    regist_info = soup.find_all('p', class_='')
    for info_reg in regist_info:
        resultat['director'].append(info_reg.text.strip())

# %%
df = pd.DataFrame.from_dict(resultat, orient='index')
df = df.transpose()

# %%
df
# Out:
#                                         names_film raiting  \
# 0                         1.\nМандалорец\n(2019– )     8.7
# 1                      2.\nНаследники\n(2018–2023)     8.8
# 2                          3.\nТед Лассо\n(2020– )     8.8
# 3            4.\nЗвёздный путь: Пикар\n(2020–2023)     7.4
# 4                           5.\nБарри\n(2018–2023)     8.4
# ..                                             ...     ...
# 195      196.\nОранжевый - хит сезона\n(2013–2019)     8.1
# 196  197.\nМир Юрского периода: Господство\n(2022)     5.6
# 197                     198.\nCSI: Vegas\n(2021– )     7.5
# 198                     199.\nВинчестеры\n(2022– )     6.3
# 199                         200.\nПаразиты\n(2019)     8.5
#
#                           janre  \
# 0    Action, Adventure, Fantasy
# 1                 Comedy, Drama
# 2          Comedy, Drama, Sport
# 3      Action, Adventure, Drama
# 4         Action, Comedy, Crime
# ..                          ...
# 195        Comedy, Crime, Drama
# 196   Action, Adventure, Sci-Fi
# 197       Crime, Drama, Mystery
# 198    Action, Adventure, Drama
# 199             Drama, Thriller
#
#                                               director
# 0    Stars:\nPedro Pascal, \nChris Bartlett, \nKate...
# 1    Stars:\nNicholas Braun, \nBrian Cox, \nKieran ...
# 2    Stars:\nJason Sudeikis, \nBrett Goldstein, \nH...
# 3    Stars:\nPatrick Stewart, \nMichelle Hurd, \nJe...
# 4    Stars:\nBill Hader, \nStephen Root, \nSarah Go...
# ..                                                 ...
# 195  Stars:\nTaylor Schilling, \nDanielle Brooks, \...
# 196  Director:\nColin Trevorrow\n| \n    Stars:\nCh...
# 197  Stars:\nPaula Newsome, \nMatt Lauria, \nMandee...
# 198  Stars:\nMeg Donnelly, \nDrake Rodger, \nNida K...
# 199  Director:\nBong Joon Ho\n| \n    Stars:\nSong ...
#
# [200 rows x 4 columns]

# %%
df['year'] = df.names_film.apply(lambda x: x.split('\n')[2])
df['names_film'] = df.names_film.apply(lambda x: x.split('\n')[1])
df['Режиссер'] = df.director.apply(lambda x: x.split('Stars')[0])
df['Режиссер'] = df['Режиссер'].str.replace('Director', '')
df['Режиссер'] = df['Режиссер'].str.replace('\n', '')
df['Режиссер'] = df['Режиссер'].str.replace(':', '')
df['Режиссер'] = df['Режиссер'].str.replace('s', '', 1)
df['Актеры'] = df.director.apply(lambda x: x.split('Stars:')[1])
df['Актеры'] = df['Актеры'].str.replace('\n', '')
df = df.drop('director', axis=1)
df = df.rename(columns={'names_film':'Наименование фильма', 'raiting':'Рейтинг', 'janre' : 'Жанр', 'year' : 'Год'})

# %%
df
# Out:
#                  Наименование фильма Рейтинг                        Жанр  \
# 0                         Мандалорец     8.7  Action, Adventure, Fantasy
# 1                         Наследники     8.8               Comedy, Drama
# 2                          Тед Лассо     8.8        Comedy, Drama, Sport
# 3               Звёздный путь: Пикар     7.4    Action, Adventure, Drama
# 4                              Барри     8.4       Action, Comedy, Crime
# ..                               ...     ...                         ...
# 195           Оранжевый - хит сезона     8.1        Comedy, Crime, Drama
# 196  Мир Юрского периода: Господство     5.6   Action, Adventure, Sci-Fi
# 197                       CSI: Vegas     7.5       Crime, Drama, Mystery
# 198                       Винчестеры     6.3    Action, Adventure, Drama
# 199                         Паразиты     8.5             Drama, Thriller
#
#              Год               Режиссер  \
# 0       (2019– )
# 1    (2018–2023)
# 2       (2020– )
# 3    (2020–2023)
# 4    (2018–2023)
# ..           ...                    ...
# 195  (2013–2019)
# 196       (2022)  Colin Trevorrow|
# 197     (2021– )
# 198     (2022– )
# 199       (2019)     Bong Joon Ho|
#
#                                                 Актеры
# 0    Pedro Pascal, Chris Bartlett, Katee Sackhoff, ...
# 1    Nicholas Braun, Brian Cox, Kieran Culkin, Pete...
# 2    Jason Sudeikis, Brett Goldstein, Hannah Waddin...
# 3    Patrick Stewart, Michelle Hurd, Jeri Ryan, Ali...
# 4    Bill Hader, Stephen Root, Sarah Goldberg, Anth...
# ..                                                 ...
# 195  Taylor Schilling, Danielle Brooks, Taryn Manni...
# 196  Chris Pratt, Bryce Dallas Howard, Laura Dern, ...
# 197  Paula Newsome, Matt Lauria, Mandeep Dhillon, J...
# 198  Meg Donnelly, Drake Rodger, Nida Khurshid, Joj...
# 199  Song Kang-ho, Lee Sun-kyun, Cho Yeo-jeong, Cho...
#
# [200 rows x 6 columns]
